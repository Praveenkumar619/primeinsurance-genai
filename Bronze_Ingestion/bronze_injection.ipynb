# %%
# %sql
CREATE SCHEMA IF NOT EXISTS primeinsurance.bronze;

# %% [markdown]
# SALES

# %%
from pyspark.sql.functions import current_timestamp, col

sales_df = (
    spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("header", "true")
        .option("inferSchema", "true")
        .option("pathGlobFilter", "*[sS][aA][lL][eE][sS]*.csv")
        .option("cloudFiles.schemaLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/schema/sales")
        .option("cloudFiles.schemaEvolutionMode", "addNewColumns")
        .load("/Volumes/primeinsurance/raw_insurance/insurance_files/")
)

sales_df = (
    sales_df
        .withColumn("source_file", col("_metadata.file_path"))
        .withColumn("load_timestamp", current_timestamp())
)

(
    sales_df.writeStream
        .format("delta")
        .option("checkpointLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/checkpoints/sales")
        .option("mergeSchema", "true")
        .trigger(availableNow=True)
        .table("primeinsurance.bronze.sales")
)

# %% [markdown]
# CUSTOMERS

# %%
from pyspark.sql.functions import current_timestamp, col

customers_df = (
    spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("header", "true")
        .option("inferSchema", "true")
        .option("pathGlobFilter", "*[cC][uU][sS][tT][oO][mM][eE][rR][sS]*.csv")
        .option("cloudFiles.schemaLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/schema/customers")
        .option("cloudFiles.schemaEvolutionMode", "addNewColumns")
        .load("/Volumes/primeinsurance/raw_insurance/insurance_files/")
)

customers_df = (
    customers_df
        .withColumn("source_file", col("_metadata.file_path"))
        .withColumn("load_timestamp", current_timestamp())
)

(
    customers_df.writeStream
        .format("delta")
        .option("checkpointLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/checkpoints/customers")
        .option("mergeSchema", "true")
        .trigger(availableNow=True)
        .table("primeinsurance.bronze.customers")
)

# %% [markdown]
# CLAIMS

# %%
from pyspark.sql.functions import current_timestamp, col

claims_df = (
    spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "json")
        .option("inferSchema", "true")
        .option("pathGlobFilter", "*[cC][lL][aA][iI][mM][sS]*.json")
        .option("cloudFiles.schemaLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/schema/claims")
        .option("cloudFiles.schemaEvolutionMode", "addNewColumns")
        .load("/Volumes/primeinsurance/raw_insurance/insurance_files/")
)

claims_df = (
    claims_df
        .withColumn("source_file", col("_metadata.file_path"))
        .withColumn("load_timestamp", current_timestamp())
)

(
    claims_df.writeStream
        .format("delta")
        .option("checkpointLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/checkpoints/claims")
        .option("mergeSchema", "true")
        .trigger(availableNow=True)
        .table("primeinsurance.bronze.claims")
)

# %% [markdown]
# POLICY

# %%
from pyspark.sql.functions import current_timestamp, col

policy_df = (
    spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("header", "true")
        .option("inferSchema", "true")
        .option("pathGlobFilter", "*[pP][oO][lL][iI][cC][yY]*.csv")
        .option("cloudFiles.schemaLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/schema/policy")
        .option("cloudFiles.schemaEvolutionMode", "addNewColumns")
        .load("/Volumes/primeinsurance/raw_insurance/insurance_files/")
)

policy_df = (
    policy_df
        .withColumn("source_file", col("_metadata.file_path"))
        .withColumn("load_timestamp", current_timestamp())
)

(
    policy_df.writeStream
        .format("delta")
        .option("checkpointLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/checkpoints/policy")
        .option("mergeSchema", "true")
        .trigger(availableNow=True)
        .table("primeinsurance.bronze.policy")
)

# %% [markdown]
# CARS

# %%
from pyspark.sql.functions import current_timestamp, col

cars_df = (
    spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("header", "true")
        .option("inferSchema", "true")
        .option("pathGlobFilter", "*[cC][aA][rR][sS]*.csv")
        .option("cloudFiles.schemaLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/schema/cars")
        .option("cloudFiles.schemaEvolutionMode", "addNewColumns")
        .load("/Volumes/primeinsurance/raw_insurance/insurance_files/")
)

cars_df = (
    cars_df
        .withColumn("source_file", col("_metadata.file_path"))
        .withColumn("load_timestamp", current_timestamp())
)

(
    cars_df.writeStream
        .format("delta")
        .option("checkpointLocation",
                "/Volumes/primeinsurance/raw_insurance/insurance_files/checkpoints/cars")
        .option("mergeSchema", "true")
        .trigger(availableNow=True)
        .table("primeinsurance.bronze.cars")
)
